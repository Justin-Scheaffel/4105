# %%
#Justin Scheaffel
#801080423
#Github Repository: https://github.com/Justin-Scheaffel/Ecgr-4105


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r'D:\Users\Justin\Downloads\D3.csv')
M=len(df)
M
########## Problem 1 ##########


x1 = df.values[:, 0]#get input values from first column
x2 = df.values[:, 1]#get input values from second column
x3 = df.values[:, 2]#get input values from third column
y = df.values[:, 3] #get output values from fourth column
m = len(y)#Number of training examples
print('x1 = ', x1[:99])
print('x2 = ', x2[:99])
print('x3 = ', x3[:99])
print('y = ', y[:99])


#Question 1: Report the linear model you found for each explanatory variable. This can be shown with the following 3 graphs
plt.scatter(x1,y, color='red',marker= '+')
plt.grid()
plt.rcParams["figure.figsize"] = (10,6)
plt.xlabel('Explanatory Variable')
plt.ylabel('Dependant Variable')
plt.title('Linear Regression for X1')
# Out:
# x1 =  [0.04040404 0.08080808 0.12121212 0.16161616 0.2020202  0.24242424
#  0.28282828 0.32323232 0.36363636 0.4040404  0.44444444 0.48484848
#  0.52525253 0.56565657 0.60606061 0.64646465 0.68686869 0.72727273
#  0.76767677 0.80808081 0.84848485 0.88888889 0.92929293 0.96969697
#  1.01010101 1.05050505 1.09090909 1.13131313 1.17171717 1.21212121
#  1.25252525 1.29292929 1.33333333 1.37373737 1.41414141 1.45454545
#  1.49494949 1.53535354 1.57575758 1.61616162 1.65656566 1.6969697
#  1.73737374 1.77777778 1.81818182 1.85858586 1.8989899  1.93939394
#  1.97979798 2.02020202 2.06060606 2.1010101  2.14141414 2.18181818
#  2.22222222 2.26262626 2.3030303  2.34343434 2.38383838 2.42424242
#  2.46464646 2.50505051 2.54545455 2.58585859 2.62626263 2.66666667
#  2.70707071 2.74747475 2.78787879 2.82828283 2.86868687 2.90909091
#  2.94949495 2.98989899 3.03030303 3.07070707 3.11111111 3.15151515
#  3.19191919 3.23232323 3.27272727 3.31313131 3.35353535 3.39393939
# ...

# %%
plt.scatter(x2,y, color='blue',marker= '+')
plt.grid()
plt.rcParams["figure.figsize"] = (10,6)
plt.xlabel('Explanatory Variable')
plt.ylabel('Dependant Variable')
plt.title('Linear Regression for X2')
# Out:
# Text(0.5, 1.0, 'Linear Regression for X2')

# %%
plt.scatter(x3,y, color='purple',marker= '+')
plt.grid()
plt.rcParams["figure.figsize"] = (10,6)
plt.xlabel('Explanatory Variable')
plt.ylabel('Dependant Variable')
plt.title('Linear Regression for X3')
# Out:
# Text(0.5, 1.0, 'Linear Regression for X3')

# %%
#Matrix of 1's
m1 = np.ones((m,1))

#Reshape before hstack
x1 = x1.reshape(m,1)
x2 = x2.reshape(m,1)
x3 = x3.reshape(m,1)

# %%
#For x1
#use hstack to add together
x = np.hstack((m1, x1))

theta = np.zeros(2)

def compute_cost(x, y, theta):
    predictions = x.dot(theta)
    errors = np.subtract(predictions, y)
    sqrErrors = np.square(errors)
    J = 1 / (2 * m) * np.sum(sqrErrors)
    
    return J

cost = compute_cost(x, y, theta)

print('The cost for given values of theta_0 and theat_1 =', cost)
# Out:
# The cost for given values of theta_0 and theat_1 = 5.483015861682611

# %%
#Gradient Descent for x1

def gradient_descent(x, y, theta, alpha, iterations):
    cost_history = np.zeros(iterations)
    for i in range(iterations):
        prediction = x.dot(theta)
        errors = np.subtract(prediction, y)
        sum_delta = (alpha / m) * x.transpose().dot(errors)
        theta = theta - sum_delta
        cost_history[i] = compute_cost(x,y,theta)
        
    return theta, cost_history

theta = [0., 0.]
iterations = 1500;
alpha = 0.01

theta, cost_history = gradient_descent(x, y, theta, alpha, iterations)
print('Final value of theta=', theta)
print('cost_history =', cost_history)
# Out:
# Final value of theta= [ 5.75752967 -1.97114532]
# cost_history = [5.4416155  5.40304386 5.36697031 ... 0.98927932 0.98925005 0.98922091]

# %%
#Question 2: Plot the Final regression model and loss over the iteration per each explanatory variable. This can be shown in the next few lines of code.

#linear regression for x1
plt.scatter(x[:,1], y, color='red', marker='+', label='Training Data')
plt.plot(x[:,1], x.dot(theta), color='green', label='Linear Regression')

plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('Explanatory Variable')
plt.ylabel('Dependta Variable')
plt.title('Linear Regression for x1')
plt.legend()

# %%
#Gradient Descent for x1
plt.plot(range(1, iterations + 1), cost_history, color = "red")
plt.rcParams["figure.figsize"] = (10,6)

plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Gradient Descent for x1')
# Out:
# Text(0.5, 1.0, 'Gradient Descent for x1')

# %%
#For x2
#use hstack to add together
x = np.hstack((m1, x2))

theta = np.zeros(2)

def compute_cost(x, y, theta):
    predictions = x.dot(theta)
    errors = np.subtract(predictions, y)
    sqrErrors = np.square(errors)
    J = 1 / (2 * m) * np.sum(sqrErrors)
    
    return J

cost = compute_cost(x, y, theta)

print('The cost for given values of theta_0 and theat_1 =', cost)
# Out:
# The cost for given values of theta_0 and theat_1 = 5.483015861682611

# %%
#Gradient Descent for x2

def gradient_descent(x, y, theta, alpha, iterations):
    cost_history = np.zeros(iterations)
    for i in range(iterations):
        prediction = x.dot(theta)
        errors = np.subtract(prediction, y)
        sum_delta = (alpha / m) * x.transpose().dot(errors)
        theta = theta - sum_delta
        cost_history[i] = compute_cost(x,y,theta)
        
    return theta, cost_history

theta = [0., 0.]
iterations = 1500;
alpha = 0.01

theta, cost_history = gradient_descent(x, y, theta, alpha, iterations)
print('Final value of theta=', theta)
print('cost_history =', cost_history)
# Out:
# Final value of theta= [0.7392744 0.5453018]
# cost_history = [5.2669085  5.07623409 4.90799786 ... 3.6201926  3.62019244 3.62019228]

# %%
#linear regression for x2
plt.scatter(x[:,1], y, color='red', marker='+', label='Training Data')
plt.plot(x[:,1], x.dot(theta), color='green', label='Linear Regression')

plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('Explanatory Variable')
plt.ylabel('Dependta Variable')
plt.title('Linear Regression for x2')
plt.legend()

# %%
#Gradient Descent for x2
plt.plot(range(1, iterations + 1), cost_history, color = "red")
plt.rcParams["figure.figsize"] = (10,6)

plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Gradient Descent for x2')
# Out:
# Text(0.5, 1.0, 'Gradient Descent for x2')

# %%
#For x3
#use hstack to add together
x = np.hstack((m1, x3))

theta = np.zeros(2)

def compute_cost(x, y, theta):
    predictions = x.dot(theta)
    errors = np.subtract(predictions, y)
    sqrErrors = np.square(errors)
    J = 1 / (2 * m) * np.sum(sqrErrors)
    
    return J

cost = compute_cost(x, y, theta)

print('The cost for given values of theta_0 and theat_1 =', cost)
# Out:
# The cost for given values of theta_0 and theat_1 = 5.483015861682611

# %%
#Gradient Descent for x3

def gradient_descent(x, y, theta, alpha, iterations):
    cost_history = np.zeros(iterations)
    for i in range(iterations):
        prediction = x.dot(theta)
        errors = np.subtract(prediction, y)
        sum_delta = (alpha / m) * x.transpose().dot(errors)
        theta = theta - sum_delta
        cost_history[i] = compute_cost(x,y,theta)
        
    return theta, cost_history

theta = [0., 0.]
iterations = 1500;
alpha = 0.01

theta, cost_history = gradient_descent(x, y, theta, alpha, iterations)
print('Final value of theta=', theta)
print('cost_history =', cost_history)
# Out:
# Final value of theta= [ 2.71943299 -0.46300206]
# cost_history = [5.366643   5.26340773 5.17178032 ... 3.65144217 3.65143712 3.6514321 ]

# %%
#linear regression for x3
plt.scatter(x[:,1], y, color='red', marker='+', label='Training Data')
plt.plot(x[:,1], x.dot(theta), color='green', label='Linear Regression')

plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('Explanatory Variable')
plt.ylabel('Dependta Variable')
plt.title('Linear Regression for x3')
plt.legend()

# %%
#Gradient Descent for x3
plt.plot(range(1, iterations + 1), cost_history, color = "red")
plt.rcParams["figure.figsize"] = (10,6)

plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Gradient Descent for x3')
# Out:
# Text(0.5, 1.0, 'Gradient Descent for x3')

# %%
#Question 3: Which explanatory variable has the lower loss (cost) for explaining the output (y)? x2 has the lower loss (cost) for explaining the output

#Question 4: Based on your training observations, describe the impact of the different learning rates on the final loss and number of training iteration. As the learning rate increases, cost tends to drop.

# %%
########## Problem 2 ##########

x1 = df.values[:, 0]#get input values from first column
x2 = df.values[:, 1]#get input values from second column
x3 = df.values[:, 2]#get input values from third column
y = df.values[:, 3] #get output values from fourth column
m = len(y)#Number of training examples
print('x1 = ', x1[:99])
print('x2 = ', x2[:99])
print('x3 = ', x3[:99])
print('y = ', y[:99])

plt.scatter(x1,y, color='red',marker= '+', label = "x1")
plt.scatter(x2,y, color='blue',marker= '+', label = "x2")
plt.scatter(x3,y, color='orange',marker= '+', label = "x3")
plt.grid()
plt.rcParams["figure.figsize"] = (10,6)
plt.xlabel('Explanatory Variable')
plt.ylabel('Dependant Variable')
plt.title('Linear Regression for x1, x2, and x3')
# Out:
# x1 =  [0.04040404 0.08080808 0.12121212 0.16161616 0.2020202  0.24242424
#  0.28282828 0.32323232 0.36363636 0.4040404  0.44444444 0.48484848
#  0.52525253 0.56565657 0.60606061 0.64646465 0.68686869 0.72727273
#  0.76767677 0.80808081 0.84848485 0.88888889 0.92929293 0.96969697
#  1.01010101 1.05050505 1.09090909 1.13131313 1.17171717 1.21212121
#  1.25252525 1.29292929 1.33333333 1.37373737 1.41414141 1.45454545
#  1.49494949 1.53535354 1.57575758 1.61616162 1.65656566 1.6969697
#  1.73737374 1.77777778 1.81818182 1.85858586 1.8989899  1.93939394
#  1.97979798 2.02020202 2.06060606 2.1010101  2.14141414 2.18181818
#  2.22222222 2.26262626 2.3030303  2.34343434 2.38383838 2.42424242
#  2.46464646 2.50505051 2.54545455 2.58585859 2.62626263 2.66666667
#  2.70707071 2.74747475 2.78787879 2.82828283 2.86868687 2.90909091
#  2.94949495 2.98989899 3.03030303 3.07070707 3.11111111 3.15151515
#  3.19191919 3.23232323 3.27272727 3.31313131 3.35353535 3.39393939
# ...

# %%
#Matrix of 1's
m1 = np.ones((m,1))

#Reshape before hstack
x1 = x1.reshape(m,1)
x2 = x2.reshape(m,1)
x3 = x3.reshape(m,1)

#For xTotal
#use hstack to add all variables together
xTotal = np.hstack((m1, x1, x2, x3))

theta = np.zeros(4)

def compute_cost(x, y, theta):
    predictions = x.dot(theta)
    errors = np.subtract(predictions, y)
    sqrErrors = np.square(errors)
    J = 1 / (2 * m) * np.sum(sqrErrors)
    
    return J

cost = compute_cost(x, y, theta)

print('The cost for given values of theta_0 and theat_1 =', cost)

#Gradient descent

def gradient_descent(x, y, theta, alpha, iterations):
    cost_history = np.zeros(iterations)
    for i in range(iterations):
        prediction = x.dot(theta)
        errors = np.subtract(prediction, y)
        sum_delta = (alpha / m) * x.transpose().dot(errors)
        theta = theta - sum_delta
        cost_history[i] = compute_cost(x,y,theta)
        
    return theta, cost_history

theta = [0., 0., 0., 0.]
iterations = 1500;
alpha = 0.01

theta, cost_history = gradient_descent(x, y, theta, alpha, iterations)
print('Final value of theta=', theta)
print('cost_history =', cost_history)
# Out:
# The cost for given values of theta_0 and theat_1 = 5.483015861682611
# Final value of theta= [ 4.21970086 -1.86902258  0.75060993 -0.1149967 ]
# cost_history = [5.18323354 4.94729184 4.75868156 ... 0.78413267 0.78398186 0.78383134]

# %%
#Question 1: Report the final linear model you found the best.  This can be shown below
#linear regression for xTotal
plt.scatter(xTotal[:,1], y, color='red', marker='+', label='Training Data')
plt.plot(xTotal[:,1], x.dot(theta), color='green', label='Linear Regression')

plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('Explanatory Variable')
plt.ylabel('Dependta Variable')
plt.title('Linear Regression for x3')
plt.legend()

# %%
#Question 2: Plot loss over the iteration.
#Gradient Descent for xTotal
plt.plot(range(1, iterations + 1), cost_history, color = "red")
plt.rcParams["figure.figsize"] = (10,6)

plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Gradient Descent for xTotal')
# Out:
# Text(0.5, 1.0, 'Gradient Descent for xTotal')

# %%
#Question 3: Based on your training observations, describe the impact of the different learning rates on the final loss and number of training iteration. As alpha increases, cost seems to decrease.
